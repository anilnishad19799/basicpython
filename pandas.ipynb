# %%
import pandas as pd
df_from_csv = pd.read_csv('C:/Users/X3/Downloads/BIA Lecture Material/pandas/data.csv')
print(df_from_csv.tail(5))
# Out:
#     Index      Customer Id First Name Last Name                Company  \
# 95     96  cb8E23e48d22Eae       Karl     Greer              Carey LLC
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson  Ware, Burns and Oneal
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra          Schmitt-Jones
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer     Fitzgerald-Harrell
# 99    100  2354a0E336A91A1   Clarence    Haynes     Le, Nash and Cross
#
#                City          Country               Phone 1  \
# 95     East Richard           Guyana   (188)169-1674x58692
# 96     New Bradview              NaN                 -3769
# 97       Ortegaland  Solomon Islands  +1-753-067-8419x7170
# 98  Lake Elijahview            Aruba         (530)311-9786
# 99        Judymouth         Honduras         (753)813-6941
#
#                    Phone 2                           Email Subscription Date  \
# 95    001-841-293-3519x614                hhart@jensen.com        30-01-2022
# ...

# %%
df_from_csv['Customer Id']
# Out:
# 0     DD37Cf93aecA6Dc
# 1     1Ef7b82A4CAAD10
# 2     6F94879bDAfE5a6
# 3     5Cef8BFA16c5e3c
# 4     053d585Ab6b3159
#            ...
# 95    cb8E23e48d22Eae
# 96    CeD220bdAaCfaDf
# 97    28CDbC0dFe4b1Db
# 98    c23d1D9EE8DEB0A
# 99    2354a0E336A91A1
# Name: Customer Id, Length: 100, dtype: object

# %%
a = [1,2,3,4]
b = [2,4,6,8]
c = [3,6,9,12]

# %%
# df_from_csv.dtypes
# df_from_csv.isnull().sum()
# df_from_csv['City'].value_counts()
# df_from_csv.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 4
#       1 # df_from_csv.dtypes
#       2 # df_from_csv.isnull().sum()
#       3 # df_from_csv['City'].value_counts()
# ----> 4 df_from_csv.corr()
#
# File c:\Users\X3\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\X3\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# ...

# %%
df_from_csv[df_from_csv["City"]=="East Richard"]
# Out:
#     Index      Customer Id First Name Last Name    Company          City  \
# 95     96  cb8E23e48d22Eae       Karl     Greer  Carey LLC  East Richard
#
#    Country              Phone 1               Phone 2             Email  \
# 95  Guyana  (188)169-1674x58692  001-841-293-3519x614  hhart@jensen.com
#
#    Subscription Date                  Website
# 95        2022-01-30  http://hayes-perez.com/

# %%
df_from_csv.drop("Country", axis=1, inplace=True)

# %%
df_from_csv.head()
# Out:
#    Index      Customer Id First Name Last Name  \
# 0      1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1      2  1Ef7b82A4CAAD10    Preston    Lozano
# 2      3  6F94879bDAfE5a6        Roy     Berry
# 3      4  5Cef8BFA16c5e3c      Linda     Olsen
# 4      5  053d585Ab6b3159     Joanna    Bender
#
#                            Company               City                 Phone 1  \
# 0                  Rasmussen Group       East Leonard            229.077.5154
# 1                      Vega-Gentry  East Jimmychester              5153435776
# 2                    Murillo-Perry      Isabelborough                   -1199
# 3  Dominguez, Mcmillan and Donovan  East Jimmychester  001-808-617-6467x12895
# 4         Martin, Lang and Andrade     West Priscilla  001-234-203-0635x76146
#
#                  Phone 2                        Email Subscription Date  \
# 0       397.884.0519x718     zunigavanessa@smith.info        24-08-2020
# ...

# %%
newdf = df_from_csv.drop("Phone 1", axis=1)

# %%
newdf.head()
# Out:
#    Index      Customer Id First Name Last Name  \
# 0      1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1      2  1Ef7b82A4CAAD10    Preston    Lozano
# 2      3  6F94879bDAfE5a6        Roy     Berry
# 3      4  5Cef8BFA16c5e3c      Linda     Olsen
# 4      5  053d585Ab6b3159     Joanna    Bender
#
#                            Company               City                Phone 2  \
# 0                  Rasmussen Group       East Leonard       397.884.0519x718
# 1                      Vega-Gentry  East Jimmychester       686-620-1820x944
# 2                    Murillo-Perry      Isabelborough    (496)978-3969x58947
# 3  Dominguez, Mcmillan and Donovan  East Jimmychester                  -9892
# 4         Martin, Lang and Andrade     West Priscilla  001-199-446-3860x3486
#
#                          Email Subscription Date                      Website  \
# 0     zunigavanessa@smith.info        24-08-2020   http://www.stephenson.com/
# ...

# %%
import matplotlib.pyplot as plt
df_from_csv['Index'].hist()
plt.show()

# %%
x = [1,2,3,4]
y = [6,7,8,9]

plt.scatter(x,y)
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %%
import matplotlib.pyplot  as plt

# %%
x = [1, 2, 3, 4, 5]
y = [10, 14, 8, 20, 12]

plt.plot(x, y, color='b')

# Adding labels and a legend
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Line Plot Example')
plt.legend()

# # Show the plot
# Out:
# C:\Users\X3\AppData\Local\Temp\ipykernel_4600\4154021005.py:10: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [10, 14, 8, 20, 12]

# Plotting the line chart
plt.plot(x, y, color='b')

# Adding labels and a legend
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Line Plot Example')
plt.legend()

# Adjust layout to avoid overlap
plt.tight_layout()

# Save the figure
plt.savefig('my_plot.pdf')

plt.show()  # This can be used if you want to display it after saving
# Optional: Show the plot if needed
# Out:
# C:\Users\X3\AppData\Local\Temp\ipykernel_4600\1268638184.py:13: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
df_from_csv.head()
# Out:
#    Index      Customer Id First Name Last Name  \
# 0      1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1      2  1Ef7b82A4CAAD10    Preston    Lozano
# 2      3  6F94879bDAfE5a6        Roy     Berry
# 3      4  5Cef8BFA16c5e3c      Linda     Olsen
# 4      5  053d585Ab6b3159     Joanna    Bender
#
#                            Company               City                 Phone 1  \
# 0                  Rasmussen Group       East Leonard            229.077.5154
# 1                      Vega-Gentry  East Jimmychester              5153435776
# 2                    Murillo-Perry      Isabelborough                   -1199
# 3  Dominguez, Mcmillan and Donovan  East Jimmychester  001-808-617-6467x12895
# 4         Martin, Lang and Andrade     West Priscilla  001-234-203-0635x76146
#
#                  Phone 2                        Email Subscription Date  \
# 0       397.884.0519x718     zunigavanessa@smith.info        24-08-2020
# ...

# %%
df_val = df_from_csv['First Name'].value_counts()
print(df_val)
# Out:
# First Name
# Sheryl      2
# Joanna      2
# Faith       2
# Shane       2
# Tom         2
#            ..
# Darrell     1
# Karl        1
# Fred        1
# Yvonne      1
# Clarence    1
# Name: count, Length: 93, dtype: int64

# %%
for iter, val in df_val.iterrow():
    print(val)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4600\829598789.py in ?()
# ----> 1 for iter, val in df_val.iterrow():
#       2     print(val)
#
# c:\Users\X3\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'iterrow'

# %%
for iter, val in df_from_csv.iterrows():
    print(val["First Name"], val["City"])
# Out:
# Sheryl East Leonard
# Preston East Jimmychester
# Roy Isabelborough
# Linda East Jimmychester
# Joanna West Priscilla
# Aimee Chavezborough
# Darren Lake Ana
# Brett Kimport
# Sheryl Robersonstad
# Michelle Elaineberg
# Carl Shannonville
# Jenna East Andrea
# Tracey South Joannamouth
# Kristine Jodyberg
# Faith Burchbury
# Miranda Desireeshire
# Caroline West Adriennestad
# Greg Lake Leslie
# Clifford Harmonview
# Joanna Jamesshire
# Maxwell East Carly
# Kiara South Alvin
# Colleen Brittanyview
# Janet Veronicamouth
# Shane Bryanville
# Marcus Kaitlyntown
# Dakota Michealshire
# Frederick South Marissatown
# Stefanie Acevedoville
# Kent North Harold
# Jack West Samuel
# Tom Cunninghamborough
# Gabriel Port Annatown
# Kaitlyn New Kaitlyn
# Faith West Marthaburgh
# Tammie East Teresa
# Nicholas South Hunter
# Jordan South Walter
# Bruce Poolefurt
# Sherry West John
# Natalie West Darius
# Bryan North Jimstad
# Wayne East Rebekahborough
# Luis North Drew
# Rhonda Lake Lindaburgh
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Sample data
data = sns.load_dataset("iris")

# Create a histogram
sns.histplot(data=setodadata, x="sepal_length", kde=True)

# Adding labels and a title
plt.xlabel("Sepal Length")
plt.ylabel("Frequency")
plt.title("Histogram of Sepal Length")

# Show the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Sample data
data = sns.load_dataset("tips")

# Create a box plot
sns.boxplot(data=data, x="day", y="total_bill", palette="Set2")

# Adding labels and a title
plt.xlabel("Day")
plt.ylabel("Total Bill")
plt.title("Box Plot of Total Bill by Day")

# Show the plot
plt.show()
# Out:
# C:\Users\X3\AppData\Local\Temp\ipykernel_4600\4259280685.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=data, x="day", y="total_bill", palette="Set2")

# %%
thurday = data[data['day']=="Thur"]

# %%
thurday.describe()
# Out:
#        total_bill        tip       size
# count   62.000000  62.000000  62.000000
# mean    17.682742   2.771452   2.451613
# std      7.886170   1.240223   1.066285
# min      7.510000   1.250000   1.000000
# 25%     12.442500   2.000000   2.000000
# 50%     16.200000   2.305000   2.000000
# 75%     20.155000   3.362500   2.000000
# max     43.110000   6.700000   6.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Sample data
data = sns.load_dataset("tips")

# Create a violin plot
sns.violinplot(data=data, x="day", y="total_bill", palette="pastel")

# Adding labels and a title
plt.xlabel("Day")
plt.ylabel("Total Bill")
plt.title("Violin Plot of Total Bill by Day")

# Show the plot
plt.show()
# Out:
# C:\Users\X3\AppData\Local\Temp\ipykernel_4600\3669529489.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=data, x="day", y="total_bill", palette="pastel")

# %%
data.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
data.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
data["species"].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
setodadata = data[data["species"]=='virginica']

# %%
setodadata
# Out:
# Empty DataFrame
# Columns: [sepal_length, sepal_width, petal_length, petal_width, species]
# Index: []

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load a sample dataset
data = sns.load_dataset("iris")

# Create a pair plot
sns.pairplot(data, hue="species", markers=["o", "s", "D"])

# Show the plot
plt.show()
# Out:
# c:\Users\X3\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\axisgrid.py:1615: UserWarning: The markers list has more values (3) than needed (1), which may not be intended.
#   func(x=x, y=y, **kwargs)
# c:\Users\X3\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\axisgrid.py:1615: UserWarning: The markers list has more values (3) than needed (1), which may not be intended.
#   func(x=x, y=y, **kwargs)
# c:\Users\X3\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\axisgrid.py:1615: UserWarning: The markers list has more values (3) than needed (1), which may not be intended.
#   func(x=x, y=y, **kwargs)
# c:\Users\X3\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\axisgrid.py:1615: UserWarning: The markers list has more values (3) than needed (1), which may not be intended.
#   func(x=x, y=y, **kwargs)
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# Load the "tips" dataset
data = sns.load_dataset("tips")
# Select relevant numeric columns
numeric_data = data[['total_bill', 'tip', 'size']]
# Calculate the correlation matrix
correlation_matrix = numeric_data.corr()
# Create a heat map
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm")
# Show the plot
plt.show()
